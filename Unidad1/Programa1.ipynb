# %% [markdown]
# <a href="https://colab.research.google.com/github/Jazmin8970/FundamentosProgramacion/blob/main/Unidad1/Programa1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
X = 5
X = "Hola Mundo"
X = True
print("El valor de x es", X )
# Out:
# El valor de x es True

# %%
base = int (input("Dame la base del triangulo "))
altura = int (input("Dame la altura del triangulo "))
area = (base * altura)/2
print("El area del triangulo es ", area)
# Out:
# Dame la base del triangulo 10
# Dame la altura del triangulo 20
# El area del triangulo es  100.0

# %%
variable1 = 30
variable2 = 50
if variable1 > variable2:
  print ( "la variable1 es mayor que la variable2")
else:
  print ("la variable2 es mayor que la variable1")
# Out:
# la variable2 es mayor que la variable1

# %%
variable1 = 70
variable2 = 50
if variable1 > variable2:
    print ( variable1, "es mayor que ", variable2)
else:
    print ( variable2, "es mayor que ", variable1)
# Out:
# 70 es mayor que  50

# %%
variable1 = 70
variable2 = 70
if variable1 > variable2:
    print ( variable1, "es mayor que ", variable2)
elif variable1 == variable2:
  print (variable1, "es igual que", variable2)
else:
    print ( variable2, "es mayor que ", variable1)
# Out:
# 70 es igual que 70

# %%
edad = int(input("Dame tu edad "))
if edad <=10:
  print("Eres un niño")
elif edad <=18:
  print("Eres un adolescente")
elif edad <=30:
  print("Eres un adulto joven")
elif edad<=65:
  print("Eres un adulto")
else:
  print("Eres un adulto mayor")
# Out:
# Dame tu edad 80
# Eres un adulto mayor

# %%
edad = int(input("Dame tu edad "))
if edad>=65:
  print("Eres un adulto")
elif edad <=30:
  print("Eres un adulto joven")
elif edad <=18:
  print("Eres un adolescente")
elif edad <=10:
  print("Eres un niño")
else:
  print("Eres un adulto mayor")
# Out:
# Dame tu edad 1
# Eres un adulto joven

# %%
edad = int(input("Dame tu edad "))
if edad>=65:
  print("Eres un adulto")
elif edad >=30:
  print("Eres un adulto joven")
elif edad >=18:
  print("Eres un adolescente")
elif edad >=10:
  print("Eres un niño")
else:
  print("Eres un adulto mayor")
# Out:
# Dame tu edad 45
# Eres un adulto joven

# %%
edad = int(input("Dame tu edad "))
if edad>=66:
  print("Eres un adulto mayor")
elif edad >=31 and edad <= 65:
  print("Eres un adulto ")
elif edad >=19  and edad <= 30:
  print("Eres un adulto joven")
elif edad >=11 and edad <=18:
  print("Eres un adolescente")
else:
  print("Eres un niño")
# Out:
# Dame tu edad 25
# Eres un adulto joven

# %%
5 > 10 # esto es un comentario, el resultado es una valor booleano que regresa verdadero o falso dependiendo si se cumple o no se cumple
# Out:
# False

# %%
10 > 5
# Out:
# True

# %%
10 > 5 and 10 > 7 and 10 > 1
# Out:
# True

# %%
#Comparamos 3 condiciones y el operador and y todas deben cupmlirse para que el resultado final sea verdadero
10 > 5 and 10 > 7 and 10 > 11
# Out:
# False

# %%
10 > 5 or 10 > 7 or 10 > 11
# Out:
# True

# %%
# si usamos instrucciones if "independientes" se puede dar el caso de que al evaluar cada una de las condiciones, todas se cumplan y el resultado no sea el deseado
edad = int(input("Dame tu edad "))
if edad<=65:
  print("Eres un adulto")
if edad <=30:
  print("Eres un adulto joven")
if edad <=18:
  print("Eres un adolescente")
if edad <=10:
  print("Eres un niño")
else:
  print("Eres un adulto mayor")
# Out:
# Dame tu edad 65
# Eres un adulto
# Eres un adulto joven
# Eres un adolescente
# Eres un niño

# %%
# Instruccion for sirve para repetir instrucciones
tabla  = 7
for i in range(10):
  print(tabla, "*", i, "=", tabla*i)
# Out:
# 7 * 0 = 0
# 7 * 1 = 7
# 7 * 2 = 14
# 7 * 3 = 21
# 7 * 4 = 28
# 7 * 5 = 35
# 7 * 6 = 42
# 7 * 7 = 49
# 7 * 8 = 56
# 7 * 9 = 63

# %%
tabla  = 7
for i in range(10, 100, 5):
  print(tabla, "*", i, "=", tabla*i)
# Out:
# 7 * 10 = 70
# 7 * 15 = 105
# 7 * 20 = 140
# 7 * 25 = 175
# 7 * 30 = 210
# 7 * 35 = 245
# 7 * 40 = 280
# 7 * 45 = 315
# 7 * 50 = 350
# 7 * 55 = 385
# 7 * 60 = 420
# 7 * 65 = 455
# 7 * 70 = 490
# 7 * 75 = 525
# 7 * 80 = 560
# 7 * 85 = 595
# 7 * 90 = 630
# 7 * 95 = 665

# %%
#tarea 07-09-26
tabla = int (input("¿Qué tabla quieres? "))
lim1 = int (input("¿Cuál es el limite inicial? "))
lim2 = int (input("¿Cuál es el limite final? "))
inte = int (input("¿Cuál es el intervalo? "))

for i in range(lim1, lim2, inte):
  print(tabla, "*", i, "=", tabla*i)
# Out:
# ¿Qué tabla quieres? 6
# ¿Cuál es el limite inicial? 0
# ¿Cuál es el limite final? 30
# ¿Cuál es el intervalo? 2
# 6 * 0 = 0
# 6 * 2 = 12
# 6 * 4 = 24
# 6 * 6 = 36
# 6 * 8 = 48
# 6 * 10 = 60
# 6 * 12 = 72
# 6 * 14 = 84
# 6 * 16 = 96
# 6 * 18 = 108
# 6 * 20 = 120
# 6 * 22 = 132
# 6 * 24 = 144
# 6 * 26 = 156
# 6 * 28 = 168

# %%
numero = 1
while numero <= 5:
 print(numero)
 print("Dentro del while")
 numero = numero + 1
print("Fuera del while")
# Out:
# 1
# Dentro del while
# 2
# Dentro del while
# 3
# Dentro del while
# 4
# Dentro del while
# 5
# Dentro del while
# Fuera del while

# %%
tabla = int (input("¿Qué tabla quieres? "))
lim1 = int (input("¿Cuál es el limite inicial? "))
lim2 = int (input("¿Cuál es el limite final? "))
inte = int (input("¿Cuál es el intervalo? "))

# agregamos la instruccion while para que valide que el valor iniciar sea mayor que el final, de lo contrario me pedirá indefinidamente el valor final hasta que sea mayor
while lim1 >= lim2:
  print("El limite final debe ser mayor que el inicio")
  lim2 = int(input ("¿Cuál es el limite final? "))

for i in range(lim1, lim2, inte):
  print(tabla, "*", i, "=", tabla*i)
# Out:
# ¿Qué tabla quieres? 5
# ¿Cuál es el limite inicial? 10
# ¿Cuál es el limite final? 1
# ¿Cuál es el intervalo? 3
# El limite final debe ser mayor que el inicio
# ¿Cuál es el limite final? 9
# El limite final debe ser mayor que el inicio
# ¿Cuál es el limite final? 15
# 5 * 10 = 50
# 5 * 13 = 65

# %% [markdown]
# # **Listas en Python**

# %%
# Podemos acceder a cada elemento o item de la lista a taves del indice o su posicion, las listas siempre empiezan en la posicion 0
alumnos = ["Ana", "Luis", "Carlos"]
print(alumnos)
print(alumnos[0])
print(alumnos[2])
# Out:
# ['Ana', 'Luis', 'Carlos']
# Ana
# Carlos

# %%
#podemos modificar el valor de un elemento de la lista usando el nombre de la lista y el indice y le asignamos el nuevo valor
print(alumnos)
alumnos[1]="Juan"
print(alumnos)
# Out:
# ['Ana', 'Luis', 'Carlos']
# ['Ana', 'Juan', 'Carlos']

# %%
# podemos especificar indices negativos y cuandi se ponen valores negativos se lee o se accede a la lista desde el final empezando con -1
print(alumnos)
print(alumnos[-1])
print(alumnos[-2])
# Out:
# ['Ana', 'Juan', 'Carlos']
# Carlos
# Juan

# %%
#El metodo append agrega un elemento al final de la lista
print(alumnos)
alumnos.append("Sandra")
print(alumnos)
# Out:
# ['Ana', 'Juan', 'Carlos']
# ['Ana', 'Juan', 'Carlos', 'Sandra']

# %%
print(alumnos)
alumnos.insert(2, "Sofía")
print(alumnos)
# Out:
# ['Ana', 'Juan', 'Carlos', 'Sandra']
# ['Ana', 'Juan', 'Sofía', 'Carlos', 'Sandra']

# %%
#remove borra un elemento de la lista especificando el valor, si existen valores repetidos, borra el primer valor que encuentra
print(alumnos)
alumnos.remove("Sofía")
print(alumnos)
# Out:
# ['Ana', 'Juan', 'Sofía', 'Carlos', 'Sandra']
# ['Ana', 'Juan', 'Carlos', 'Sandra']

# %%
print(alumnos[2])
#la siguiente linea marca error porque queremos acceder a un indice que no existe
#la lista tiene unicamente 4 elementos y queremos acceder al 7 que no existe
print(alumnos[7])
# Out:
# Carlos
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_1703/3255721401.py in <cell line: 0>()
#       1 print(alumnos[2])
# ----> 2 print(alumnos[7])
#
# IndexError: list index out of range

# %%
#pop me permite borrar un elemento de la lista especificando su posicion
print(alumnos)
alumnos.pop(1)
print(alumnos)
# Out:
# ['Ana', 'Juan', 'Carlos', 'Sandra']
# ['Ana', 'Carlos', 'Sandra']

# %%
#del me permite borrar un elemento de la lista especificando su posicion
print(alumnos)
del alumnos[1]
print(alumnos)
# Out:
# ['Ana', 'Carlos', 'Sandra']
# ['Ana', 'Sandra']

# %%
# la funcion len me permite conocer el numero de elementos de la lista
print("Numero de elementos o items en la lista", len(alumnos))
# Out:
# Numero de elementos o items en la lista 2

# %%
alumnos.append("Sandra","Carlos",)
print(alumnos)
for x in alumnos:
print(x)
# Out:
#   File "/tmp/ipykernel_1703/1258410490.py", line 4
#     print(x)
#     ^
# IndentationError: expected an indented block after 'for' statement on line 3
