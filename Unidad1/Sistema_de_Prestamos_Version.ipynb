# %% [markdown]
# <a href="https://colab.research.google.com/github/Jazmin8970/FundamentosProgramacion/blob/main/Unidad1/Sistema_de_Prestamos_Version.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#=========================================
# SISTEMA DE PRÉSTAMOS
# Versión 1 - Programación básica y uso de listas
#=========================================

# Lista de alumnos activos en el sistema
alumnos = [ "26040200","26040201","26040202","26040203","26040204"]

#Cada valor en la lista e computadoras tiene su lista correspondiente con el
# aula donde esta ubicada, el software instalado y el estado de esa computadora
computadoras = ["PC-LC1-01", "PC-LC1-02", "PC-LC1-03",
                "PC-LC2-01", "PC-LC2-02", "PC-LC2-03",
                "PC-LC3-01", "PC-LC3-02", "PC-LC3-03", "PC-LC3-04"]

aulas = ["LC1", "LC1", "LC1",
         "LC2", "LC2", "LC2",
         "LC3", "LC3", "LC3", "LC3"]

software = ["Python, VS Code", "Python, Java, VS Code", "AutoCAD, MATLAB",
            "Python, VS Code", "Python, Java, VS Code", "AutoCAD, MATLAB",
            "Python, VS Code", "Python, Java, VS Code", "AutoCAD, MATLAB", "Python, VS Code"]

estados = ["Disponible", "Prestada", "Reservada",
          "Disponible", "Prestada", "Reservada",
          "Disponible", "Prestada", "Reservada", "Mantenimiento"]

# MENÚ PRINCIPAL
# Usamos un ciclo While que se repetirá indefinidamente hasta que el usuario
# teclee la opción 7 (salir) o cualquier numero superior a 7
opcion = 0
while opcion <= 6:
  print("\n==========================")
  print("    SISTEMA DE PRESTAMOS    ")
  print("\n==========================")
  print("1. Consultar computadoras")
  print("2. Buscar por software")
  print("3. Solicitar prestamo")
  print("4. Devolver computadora")
  print("5. Crear reservvación")
  print("6. Agregar computadora")
  print("7. Salir")
  print("\n==========================")
  opcion = int(input("Seleccione una opción: "))

  #1. Consultar computadora
  # si el usuario selecciono la opcion 1 se hace un ciclo (for) que recorre
  # toda la lista de computadoras e imprime los valores de las demás listas
  if opcion == 1:
    for i in range(len(computadoras)):
      print("Aula: ", aulas[i])
      print("ID: ", computadoras[i])
      print("Software: ", software[i])
      print("Estado: ", estados[i])
      print("------------------------")
# Out:
# ==========================
#     SISTEMA DE PRESTAMOS
#
# ==========================
# 1. Consultar computadoras
# 2. Buscar por software
# 3. Solicitar prestamo
# 4. Devolver computadora
# 5. Crear reservvación
# 6. Agregar computadora
# 7. Salir
#
# ==========================
# Seleccione una opción: 1
# Aula:  LC1
# ID:  PC-LC1-01
# Software:  Python, VS Code
# Estado:  Disponible
# ------------------------
# Aula:  LC1
# ID:  PC-LC1-02
# Software:  Python, Java, VS Code
# Estado:  Prestada
# ------------------------
# Aula:  LC1
# ID:  PC-LC1-03
# Software:  AutoCAD, MATLAB
# Estado:  Reservada
# ------------------------
# Aula:  LC2
# ID:  PC-LC2-01
# Software:  Python, VS Code
# Estado:  Disponible
# ------------------------
# Aula:  LC2
# ID:  PC-LC2-02
# Software:  Python, Java, VS Code
# Estado:  Prestada
# ------------------------
# Aula:  LC2
# ID:  PC-LC2-03
# Software:  AutoCAD, MATLAB
# Estado:  Reservada
# ------------------------
# Aula:  LC3
# ID:  PC-LC3-01
# Software:  Python, VS Code
# Estado:  Disponible
# ------------------------
# Aula:  LC3
# ID:  PC-LC3-02
# Software:  Python, Java, VS Code
# Estado:  Prestada
# ------------------------
# Aula:  LC3
# ID:  PC-LC3-03
# Software:  AutoCAD, MATLAB
# Estado:  Reservada
# ------------------------
# Aula:  LC3
# ID:  PC-LC3-04
# Software:  Python, VS Code
# Estado:  Mantenimiento
# ------------------------
#
# ==========================
#     SISTEMA DE PRESTAMOS
#
# ==========================
# 1. Consultar computadoras
# 2. Buscar por software
# 3. Solicitar prestamo
# 4. Devolver computadora
# 5. Crear reservvación
# 6. Agregar computadora
# 7. Salir
#
# ==========================
# Seleccione una opción: 2
#
# ==========================
#     SISTEMA DE PRESTAMOS
#
# ==========================
# 1. Consultar computadoras
# 2. Buscar por software
# 3. Solicitar prestamo
# 4. Devolver computadora
# 5. Crear reservvación
# 6. Agregar computadora
# 7. Salir
#
# ==========================
# Seleccione una opción: 3
#
# ==========================
#     SISTEMA DE PRESTAMOS
#
# ==========================
# 1. Consultar computadoras
# 2. Buscar por software
# 3. Solicitar prestamo
# 4. Devolver computadora
# 5. Crear reservvación
# 6. Agregar computadora
# 7. Salir
#
# ==========================
# Seleccione una opción: 6
#
# ==========================
#     SISTEMA DE PRESTAMOS
#
# ==========================
# 1. Consultar computadoras
# 2. Buscar por software
# 3. Solicitar prestamo
# 4. Devolver computadora
# 5. Crear reservvación
# 6. Agregar computadora
# 7. Salir
#
# ==========================
# Seleccione una opción: 7
